# %% [markdown]
# <a href="https://colab.research.google.com/github/Deamoe/Machine-Learning-with-Python-Bootcamp/blob/main/orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of addition

# %%
a = 2
b = 3
c=a+b

print(c)
# Out:
# 5

# %% [markdown]
# Example of string

# %%
greetings= "advise na, proff"
print(greetings)
# Out:
# advise na, proff
