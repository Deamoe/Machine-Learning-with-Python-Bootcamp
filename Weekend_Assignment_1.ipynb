# %% [markdown]
# <a href="https://colab.research.google.com/github/Deamoe/Machine-Learning-with-Python-Bootcamp/blob/main/Weekend_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Jeremiah Sackie - May 24, 2026**

# %% [markdown]
# **Part 1: Understanding print()-Variable vs Quoted Text (3 problems)**

# %% [markdown]
# #Problem 1

# %%
Liberia = 1847

print(Liberia) # the first print statement will output "1847" which is the value of the variable "Liberia".
print("Liberia") # Ihe second print will output "Liberia" it self.
# Out:
# 1847
# Liberia

# %% [markdown]
# The first print statement output '1847', which is the value of the variable 'Liberia' because Liberia is not placed in a quotation mark. While the second print statement output 'Liberia' itself because it is placed in a quotation mark, making it a string.

# %% [markdown]
# # Problem 2

# %%
# this is a varible:

country = "Liberia"

#print statement:

print(country) # this print statement will disply the variable's value which is 'Liberia'
print(country, "became independece in 1847") # this print statement will output the variable's value and the string 'became independence in 1847'.
# Out:
# Liberia
# Liberia became independece in 1847

# %% [markdown]
# #Problem 3

# %%
#variable:

Year = 1847

#print statement:

print("This year is \"1847\"") #
# Out:
# This year is "1847"

# %% [markdown]
# Part 2: Creating Variables with Different Data Types (3 problems)

# %% [markdown]
# #Problem 4

# %%
#variables:
market_name = "Gobachop Market"
total_market_table = 150
price_per_bag = 3200.50
is_market_open = True

#print statements:
print("The Market is Called", market_name)
print( "It has", total_market_table, "market tables")
print("Sugar is sold for", price_per_bag, "per bag")
print("Is the market open?", is_market_open)

#print variable types:
print(type(market_name))
print(type(total_market_table))
print(type(price_per_bag))
print(type(is_market_open))
# Out:
# The Market is Called Gobachop Market
# It has 150 market tables
# Sugar is sold for 3200.5 per bag
# Is the market open? True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# #Problem 5

# %%
current_price = 2250.75
quantity = 10

print("Total cost for 10 bags:", current_price * quantity, "LRD")
# Out:
# Total cost for 10 bags: 22507.5 LRD

# %% [markdown]
# #Problem 6

# %%
has_scarcity = False
is_rainy = True

print("There is shortage food.", has_scarcity)
print("It is raining outside.", is_rainy)
# Out:
# There is shortage food. False
# It is raining outside. True

# %% [markdown]
# Part 3: Arithmetic with Variables - Market Scenario (4 problems)

# %% [markdown]
# #Problem 7 - Total revenie

# %%
price_per_bag = 800
quantity = 25

print("Total cost for 25 bags:", price_per_bag * quantity, "LRD")
# Out:
# Total cost for 25 bags: 20000 LRD

# %% [markdown]
# #Problem 8 - Price increase

# %%
today_price = 3200
price_increase = 150

print("Tomorrow price increase:", today_price+price_increase, "LRD")
# Out:
# Tomorrow price increase: 3350 LRD

# %% [markdown]
# #Problem 9 - Splitting cost

# %%
onions_cost = 1800
number_of_traders = 3

print("Cost per trader:", onions_cost/number_of_traders, "LRD")
# Out:
# Cost per trader: 600.0 LRD

# %% [markdown]
# #Problem 10 - Discount on a gallon of palm oil

# %%
gallon_of_palm_oil_cost = 2500
discount = 0.10

print("Discounted price:", gallon_of_palm_oil_cost * discount, "LRD")
print(" Final price:", gallon_of_palm_oil_cost - discount, "LRD")
# Out:
# Discounted price: 250.0 LRD
#  Final price: 2499.9 LRD

# %% [markdown]
# Part 4: Mixing Variables and Print (2 problems)

# %% [markdown]
# #Problem 11 - Variables names vs Quoted strings

# %% [markdown]
# The code below will print the following:
#
# cassava
#
# item
#
# 800
#
# price

# %%
item = "cassava"
price = 800

print(item)
print("item")
print(price)
print("price")

# print(item) prints cassava because item is not in a quotation and 'cassava' is the value of the variable 'item'.
# print("item") prints item because item itself is in a quotation.
# Out:
# cassava
# item
# 800
# price

# %% [markdown]
# #Problem 12 - Using Variables inside messages

# %%
product = "papper"
cost = 150.50

print("One bag of", product, "costs", cost, "LRD")
# Out:
# One bag of papper costs 150.5 LRD
