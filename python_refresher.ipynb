# %% [markdown]
# <a href="https://colab.research.google.com/github/Deamoe/Machine-Learning-with-Python-Bootcamp/blob/main/python_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
#Create and labeled storage basket and put in a number inside
tomato_price = 150
papper_price = 80

#pull the value out of the basket
print (tomato_price)
print (papper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
# THE CLAUS (Features grouped as x)

rainfall_mm = 45.2    #clue 1
bags_avalible = 100   #clue 1

# --- THE CLUE (Target labeled as y) ---
predicted_price = 3200    #What our AI calculates

print("Input (x):", rainfall_mm, "mm rain," , bags_avalible, "bags. ")
print("Output (y):", predicted_price, "LRD. ")
# Out:
# Input (x): 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding print statement

# %%
Liberia = 1847
print(Liberia)     # Value will appres
print("Liberia")   # Text will appear
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Variables

# %%
Plum = 50

print("plum previous price was:", Plum)
Plum = 80

print("Plum new price is:" , Plum)
# Out:
# plum previous price was: 50
# Plum new price is: 80

# %% [markdown]
# Data Types

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stail_is_open = True

print(type(quantity))
print(type(price))
print(type(item_name))
print(type(stail_is_open))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
