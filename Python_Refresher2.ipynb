# %% [markdown]
# <a href="https://colab.research.google.com/github/Deamoe/Machine-Learning-with-Python-Bootcamp/blob/main/Python_Refresher2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables (ordinary scaffold)

# %%
# create a labeled storage basket and put a number inside

tomato_price = 150
papper_price = 80

# Pull the value out of the basket
print(tomato_price)
print(papper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
# THE CLUES (Features grouped as x)
rainfall_m = 45.2   # Clue 1
bags_avalible = 100 #Clue 2

# The GOAL (Target labeled as y)
predicted_price = 3200   # What our AI calculates

print("Input (x):", rainfall_m, bags_avalible, "bags")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Input (x): 45.2 100 bags
# Output (y): 3200 LRD.

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item = "tomatoes"
stall_is_open = True

print(type(quantity))
print(type(price))
print(type(item))
print(type(stall_is_open))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Type Conversion

# %%
raw_input = "150"
price = int(raw_input)
print(price + 50)
# Out:
# 200

# %%
total_cost = 304.5
message = "your total is LRD" + str(total_cost)
print(message)
# Out:
# your total is LRD304.5

# %% [markdown]
# List (Ordinary Scaffold)

# %%
goods = ["tomatoes", "pappers", "onions", "rice"]
print(goods)
print(goods[0])
print(goods[2])
# Out:
# ['tomatoes', 'pappers', 'onions', 'rice']
# tomatoes
# onions

# %%
print(goods[0:2])
# Out:
# ['tomatoes', 'pappers']

# %%
print(goods[0:3])
# Out:
# ['tomatoes', 'pappers', 'onions']

# %%
print(goods[0:4])
# Out:
# ['tomatoes', 'pappers', 'onions', 'rice']

# %% [markdown]
# List (ML Anchor)

# %%
loose_list = [3100, 3200, 3250]
# ML ready create: double brackets [[]]
create_matrix = [[3100], [3200], [3150]]

print("Rejected by AI:", loose_list)
print("Accepted by AI (create):", create_matrix)
# Out:
# Rejected by AI: [3100, 3200, 3250]
# Accepted by AI (create): [[3100], [3200], [3150]]

# %% [markdown]
# f-Strings For Clean Reporting

# %%
model_accuracy = 0.9456
predicted_value = 3500

print(f"Ma Christiana, our market AI model is {model_accuracy:.1%}.")
print(f"Predicted price for rice at Red Light is: {predicted_value} LRD.")
# Out:
# Ma Christiana, our market AI model is 94.6%.
# Predicted price for rice at Red Light is: 3500 LRD.

# %% [markdown]
# Dictionary

# %%
stall_prices = {
"tomatoes": 150,
"pappers": 80,
"onions": 60,
}
print(stall_prices["tomatoes"])
print(stall_prices["pappers"])
# Out:
# 150
# 80

# %%
model_settings = {
    "learning_rate": 0.001,
    "algorithm": "Random Forest",
    "number_of_trees": 100
}
print(f"Initializing {model_settings['algorithm']} engine...")
print(f"Running with {model_settings['number_of_trees']} trees.")
# Out:
# Initializing Random Forest engine...
# Running with 100 trees.

# %% [markdown]
# Liberies (Importing Toolboxes)

# %%
import math

error_rate = 625
root_error = math.sqrt(error_rate)
print(f"Root Margin of Error: {root_error} LRD.")
# Out:
# Root Margin of Error: 25.0 LRD.

# %% [markdown]
# Method vs Attribute

# %%
import pandas as pd

data = pd.DataFrame ({
    "Owner": ["Ma Musu", "Sia"],
    "Revenue": [5000, 7000]
})

# ATTRIBUTE (no parentheses)
print(f"Data Grid Shape: {data.shape}")

# METHOD (with parentheses)
print("First row:")
print(data.head(1))
# Out:
# Data Grid Shape: (2, 2)
# First row:
#      Owner  Revenue
# 0  Ma Musu     5000
